# %%
import pandas as pd
import pyreadstat

# %%
lev_05_path = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\delete\raw-data\LEVEL - 05 ( Sec 5 & 6).dta"
df = pd. .read_dta(lev_05_path)
# df.to_csv(csv_file_path, index=False, encoding='utf-8')
# Out:
#   Cell In[3], line 2
#     df = pd. .read_dta(lev_05_path)
#              ^
# SyntaxError: invalid syntax

# %%
lev_04_path = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\delete\raw-data\LEVEL - 04 (Section 4.1).sav"
df, meta = pyreadstat.read_sav(lev_04_path)

# %%
df[df['State'] == '23']
# Out:
#        Survey_Name  Year FSU_Serial_No Sector State NSS_Region District  \
# 9820          HCES  2024         44085      1    23        232       26
# 9821          HCES  2024         44085      1    23        232       26
# 9822          HCES  2024         44085      1    23        232       26
# 9823          HCES  2024         44085      1    23        232       26
# 9824          HCES  2024         44085      1    23        232       26
# ...            ...   ...           ...    ...   ...        ...      ...
# 261752        HCES  2024         25137      2    23        232       10
# 261753        HCES  2024         25137      2    23        232       10
# 261754        HCES  2024         25137      2    23        232       10
# 261755        HCES  2024         25137      2    23        232       10
# 261756        HCES  2024         25137      2    23        232       10
#
#        Stratum Sub_stratum Panel  ... Online_Vegetables Online_Fresh_Fruits  \
# ...
