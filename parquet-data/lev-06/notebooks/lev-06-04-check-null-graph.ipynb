# %%
path = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\parquet-data\lev-06\data\lev-06_merged.parquet"

# import 
import pandas as pd
import polars as pl
import missingno as msgo
import matplotlib.pyplot as plt
import seaborn as sns

# Functions define for plot null
def plot_null(df: pd.DataFrame):
    msgo.bar(df)
    msgo.dendrogram(df)
    msgo.heatmap(df)
    msgo.matrix(df)

# Import Data and filter
pdf = pl.read_parquet(path)
display(f"Before Filtering the shape {pdf.shape}")
pdf = pdf.filter(
    pl.col('State') == '23'
)
display(f"After Filter the shape {pdf.shape}")

# ------------------------ Our useful variables are 
# ===============================

cols = [
'Total_Consumption_Quantity',
'Total_Consumption_Value',
'Source',
'Multiplier',
]

pdf = pdf[cols]

display(f"Desire Filter shape {pdf.shape}")

# str -> int 
pdf = pdf.with_columns(
    [pl.col(col).cast(pl.Int16, strict=False) for col in pdf.columns]
)

display(pdf.schema)

# MP Data
mp_df = pdf.to_pandas()

print("Percentage of null values ")
for col in mp_df.columns:
    null_percentage = (mp_df[col].isnull().sum() / mp_df.shape[0]) * 100
    print(f"{col} ---> {null_percentage:.2f}%")
    
plot_null(mp_df)
# Out:
# 'Before Filtering the shape (3514528, 23)'
# 'After Filter the shape (193424, 23)'
# 'Desire Filter shape (193424, 4)'
# Schema([('Total_Consumption_Quantity', Int16),
#         ('Total_Consumption_Value', Int16),
#         ('Source', Int16),
#         ('Multiplier', Int16)])
# Percentage of null values
# Total_Consumption_Quantity ---> 97.22%
# Total_Consumption_Value ---> 0.00%
# Source ---> 29.99%
# Multiplier ---> 89.29%
