# %%
path = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\parquet-data\lev-11\data\lev-11_merged.parquet"

# import 
import pandas as pd
import polars as pl
import missingno as msgo
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import Data and filter
pdf = pl.read_parquet(path)
display(f"Before Filtering the shape {pdf.shape}")
pdf = pdf.filter(
    pl.col('State') == '23'
)
display(f"After Filter the shape {pdf.shape}")
# Out:
# 'Before Filtering the shape (523906, 59)'
# 'After Filter the shape (28210, 59)'

# %%
online_cols = [
'Online_Clothing',
'Online_Footwear',
'Online_Furniture',
'Online_Mobile',
'Online_PersonalGoods',
'Online_RecreationGoods',
'Online_HouseholdAppliances',
'Online_Crockery',
'Online_SportsGoods',
'Online_MedicalEquipment',
'Online_Bedding',
]

free_cols = [
'Free_Laptop',
'Num_Free_Laptop',
'Free_Tablet',
'Num_Free_Tablet',
'Free_Mobile',
'Num_Free_Mobile',
'Free_Bicycle',
'Num_Free_Bicycle',
'Free_Scooter',
'Num_Free_Scooter',
'Free_Clothing',
'Num_Free_Clothing',
'Free_Footwear',
'Num_Free_Footwear',
'Free_Other',
'Num_Free_Other',
]

possess_cols = [
'Possess_Television',
'Possess_Radio',
'Possess_Laptop',
'Possess_Mobile',
'Possess_Bicycle',
'Possess_Scooter',
'Possess_Car',
'Possess_Truck',
'Possess_AnimalCart',
'Possess_Refrigerator',
'Possess_WashingMachine',
'Possess_AirCooler',
'TV_Facility_Type',
]

all_cols = (
    online_cols 
    + free_cols
    + possess_cols
)
pdf = pdf[all_cols]

display(f"Desire Filter shape {pdf.shape}")
# Out:
# 'Desire Filter shape (28210, 40)'

# %%
# str -> int 
pdf = pdf.with_columns(
    [pl.col(col).cast(pl.Int16, strict=False) for col in pdf.columns]
)

display(pdf.schema)
# Out:
# Schema([('Online_Clothing', Int16),
#         ('Online_Footwear', Int16),
#         ('Online_Furniture', Int16),
#         ('Online_Mobile', Int16),
#         ('Online_PersonalGoods', Int16),
#         ('Online_RecreationGoods', Int16),
#         ('Online_HouseholdAppliances', Int16),
#         ('Online_Crockery', Int16),
#         ('Online_SportsGoods', Int16),
#         ('Online_MedicalEquipment', Int16),
#         ('Online_Bedding', Int16),
#         ('Free_Laptop', Int16),
#         ('Num_Free_Laptop', Int16),
#         ('Free_Tablet', Int16),
#         ('Num_Free_Tablet', Int16),
#         ('Free_Mobile', Int16),
#         ('Num_Free_Mobile', Int16),
#         ('Free_Bicycle', Int16),
#         ('Num_Free_Bicycle', Int16),
#         ('Free_Scooter', Int16),
#         ('Num_Free_Scooter', Int16),
#         ('Free_Clothing', Int16),
#         ('Num_Free_Clothing', Int16),
#         ('Free_Footwear', Int16),
#         ('Num_Free_Footwear', Int16),
#         ('Free_Other', Int16),
#         ('Num_Free_Other', Int16),
#         ('Possess_Television', Int16),
#         ('Possess_Radio', Int16),
#         ('Possess_Laptop', Int16),
#         ('Possess_Mobile', Int16),
#         ('Possess_Bicycle', Int16),
#         ('Possess_Scooter', Int16),
#         ('Possess_Car', Int16),
#         ('Possess_Truck', Int16),
#         ('Possess_AnimalCart', Int16),
#         ('Possess_Refrigerator', Int16),
#         ('Possess_WashingMachine', Int16),
#         ('Possess_AirCooler', Int16),
#         ('TV_Facility_Type', Int16)])

# %% [markdown]
# # Online

# %%
pdf[online_cols].null_count()
# Out:
# shape: (1, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Online_Cl ┆ Online_Fo ┆ Online_Fu ┆ Online_Mo ┆ … ┆ Online_Cr ┆ Online_Sp ┆ Online_Me ┆ Online_B │
# │ othing    ┆ otwear    ┆ rniture   ┆ bile      ┆   ┆ ockery    ┆ ortsGoods ┆ dicalEqui ┆ edding   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ pment     ┆ ---      │
# │ u32       ┆ u32       ┆ u32       ┆ u32       ┆   ┆ u32       ┆ u32       ┆ ---       ┆ u32      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ u32       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 23808     ┆ 25176     ┆ 28196     ┆ 27966     ┆ … ┆ 28108     ┆ 28028     ┆ 28182     ┆ 27896    │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
for col in pdf[online_cols].columns:
    display(pdf[col].value_counts())
# Out:
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ Online_Clothing ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ null            ┆ 23808 │
# │ 1               ┆ 4402  │
# └─────────────────┴───────┘
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ Online_Footwear ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ null            ┆ 25176 │
# │ 1               ┆ 3034  │
# └─────────────────┴───────┘
# shape: (2, 2)
# ┌──────────────────┬───────┐
# │ Online_Furniture ┆ count │
# │ ---              ┆ ---   │
# │ i16              ┆ u32   │
# ╞══════════════════╪═══════╡
# │ null             ┆ 28196 │
# │ 1                ┆ 14    │
# └──────────────────┴───────┘
# shape: (2, 2)
# ┌───────────────┬───────┐
# │ Online_Mobile ┆ count │
# │ ---           ┆ ---   │
# │ i16           ┆ u32   │
# ╞═══════════════╪═══════╡
# │ 1             ┆ 244   │
# │ null          ┆ 27966 │
# └───────────────┴───────┘
# shape: (2, 2)
# ┌──────────────────────┬───────┐
# │ Online_PersonalGoods ┆ count │
# │ ---                  ┆ ---   │
# │ i16                  ┆ u32   │
# ╞══════════════════════╪═══════╡
# │ 1                    ┆ 622   │
# │ null                 ┆ 27588 │
# └──────────────────────┴───────┘
# shape: (2, 2)
# ┌────────────────────────┬───────┐
# │ Online_RecreationGoods ┆ count │
# │ ---                    ┆ ---   │
# │ i16                    ┆ u32   │
# ╞════════════════════════╪═══════╡
# │ 1                      ┆ 72    │
# │ null                   ┆ 28138 │
# └────────────────────────┴───────┘
# shape: (2, 2)
# ┌────────────────────────────┬───────┐
# │ Online_HouseholdAppliances ┆ count │
# │ ---                        ┆ ---   │
# │ i16                        ┆ u32   │
# ╞════════════════════════════╪═══════╡
# │ null                       ┆ 28140 │
# │ 1                          ┆ 70    │
# └────────────────────────────┴───────┘
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ Online_Crockery ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ null            ┆ 28108 │
# │ 1               ┆ 102   │
# └─────────────────┴───────┘
# shape: (2, 2)
# ┌────────────────────┬───────┐
# │ Online_SportsGoods ┆ count │
# │ ---                ┆ ---   │
# │ i16                ┆ u32   │
# ╞════════════════════╪═══════╡
# │ 1                  ┆ 182   │
# │ null               ┆ 28028 │
# └────────────────────┴───────┘
# shape: (2, 2)
# ┌─────────────────────────┬───────┐
# │ Online_MedicalEquipment ┆ count │
# │ ---                     ┆ ---   │
# │ i16                     ┆ u32   │
# ╞═════════════════════════╪═══════╡
# │ null                    ┆ 28182 │
# │ 1                       ┆ 28    │
# └─────────────────────────┴───────┘
# shape: (2, 2)
# ┌────────────────┬───────┐
# │ Online_Bedding ┆ count │
# │ ---            ┆ ---   │
# │ i16            ┆ u32   │
# ╞════════════════╪═══════╡
# │ 1              ┆ 314   │
# │ null           ┆ 27896 │
# └────────────────┴───────┘

# %%
for col in pdf[online_cols].columns:
    pdf = pdf.with_columns(
    pl.col(col).fill_null(strategy='zero')
)

# %% [markdown]
# # Free

# %%
for col in pdf[free_cols].columns:
    display(pdf[col].value_counts())
# Out:
# shape: (1, 2)
# ┌─────────────┬───────┐
# │ Free_Laptop ┆ count │
# │ ---         ┆ ---   │
# │ i16         ┆ u32   │
# ╞═════════════╪═══════╡
# │ null        ┆ 28210 │
# └─────────────┴───────┘
# shape: (1, 2)
# ┌─────────────────┬───────┐
# │ Num_Free_Laptop ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ null            ┆ 28210 │
# └─────────────────┴───────┘
# shape: (2, 2)
# ┌─────────────┬───────┐
# │ Free_Tablet ┆ count │
# │ ---         ┆ ---   │
# │ i16         ┆ u32   │
# ╞═════════════╪═══════╡
# │ 1           ┆ 4     │
# │ null        ┆ 28206 │
# └─────────────┴───────┘
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ Num_Free_Tablet ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ null            ┆ 28206 │
# │ 1               ┆ 4     │
# └─────────────────┴───────┘
# shape: (2, 2)
# ┌─────────────┬───────┐
# │ Free_Mobile ┆ count │
# │ ---         ┆ ---   │
# │ i16         ┆ u32   │
# ╞═════════════╪═══════╡
# │ null        ┆ 28208 │
# │ 1           ┆ 2     │
# └─────────────┴───────┘
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ Num_Free_Mobile ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ 1               ┆ 2     │
# │ null            ┆ 28208 │
# └─────────────────┴───────┘
# shape: (2, 2)
# ┌──────────────┬───────┐
# │ Free_Bicycle ┆ count │
# │ ---          ┆ ---   │
# │ i16          ┆ u32   │
# ╞══════════════╪═══════╡
# │ 1            ┆ 100   │
# │ null         ┆ 28110 │
# └──────────────┴───────┘
# shape: (3, 2)
# ┌──────────────────┬───────┐
# │ Num_Free_Bicycle ┆ count │
# │ ---              ┆ ---   │
# │ i16              ┆ u32   │
# ╞══════════════════╪═══════╡
# │ 2                ┆ 10    │
# │ null             ┆ 28110 │
# │ 1                ┆ 90    │
# └──────────────────┴───────┘
# shape: (2, 2)
# ┌──────────────┬───────┐
# │ Free_Scooter ┆ count │
# │ ---          ┆ ---   │
# │ i16          ┆ u32   │
# ╞══════════════╪═══════╡
# │ 1            ┆ 4     │
# │ null         ┆ 28206 │
# └──────────────┴───────┘
# shape: (2, 2)
# ┌──────────────────┬───────┐
# │ Num_Free_Scooter ┆ count │
# │ ---              ┆ ---   │
# │ i16              ┆ u32   │
# ╞══════════════════╪═══════╡
# │ null             ┆ 28206 │
# │ 1                ┆ 4     │
# └──────────────────┴───────┘
# shape: (2, 2)
# ┌───────────────┬───────┐
# │ Free_Clothing ┆ count │
# │ ---           ┆ ---   │
# │ i16           ┆ u32   │
# ╞═══════════════╪═══════╡
# │ null          ┆ 26516 │
# │ 1             ┆ 1694  │
# └───────────────┴───────┘
# shape: (13, 2)
# ┌───────────────────┬───────┐
# │ Num_Free_Clothing ┆ count │
# │ ---               ┆ ---   │
# │ i16               ┆ u32   │
# ╞═══════════════════╪═══════╡
# │ 5                 ┆ 4     │
# │ 8                 ┆ 8     │
# │ 7                 ┆ 2     │
# │ 9                 ┆ 2     │
# │ 12                ┆ 2     │
# │ …                 ┆ …     │
# │ null              ┆ 26516 │
# │ 15                ┆ 2     │
# │ 10                ┆ 2     │
# │ 6                 ┆ 88    │
# │ 1                 ┆ 506   │
# └───────────────────┴───────┘
# shape: (2, 2)
# ┌───────────────┬───────┐
# │ Free_Footwear ┆ count │
# │ ---           ┆ ---   │
# │ i16           ┆ u32   │
# ╞═══════════════╪═══════╡
# │ 1             ┆ 70    │
# │ null          ┆ 28140 │
# └───────────────┴───────┘
# shape: (3, 2)
# ┌───────────────────┬───────┐
# │ Num_Free_Footwear ┆ count │
# │ ---               ┆ ---   │
# │ i16               ┆ u32   │
# ╞═══════════════════╪═══════╡
# │ 1                 ┆ 48    │
# │ null              ┆ 28140 │
# │ 2                 ┆ 22    │
# └───────────────────┴───────┘
# shape: (2, 2)
# ┌────────────┬───────┐
# │ Free_Other ┆ count │
# │ ---        ┆ ---   │
# │ i16        ┆ u32   │
# ╞════════════╪═══════╡
# │ null       ┆ 27570 │
# │ 1          ┆ 640   │
# └────────────┴───────┘
# shape: (26, 2)
# ┌────────────────┬───────┐
# │ Num_Free_Other ┆ count │
# │ ---            ┆ ---   │
# │ i16            ┆ u32   │
# ╞════════════════╪═══════╡
# │ 3              ┆ 16    │
# │ 32             ┆ 2     │
# │ 35             ┆ 2     │
# │ 9              ┆ 30    │
# │ 8              ┆ 62    │
# │ …              ┆ …     │
# │ 14             ┆ 18    │
# │ null           ┆ 27570 │
# │ 15             ┆ 12    │
# │ 4              ┆ 54    │
# │ 22             ┆ 2     │
# └────────────────┴───────┘

# %% [markdown]
# # Filter Features

# %%
online_cols = [
'Online_Clothing',
'Online_Footwear',
]

free_cols = [
'Free_Clothing',
'Num_Free_Clothing',
]

possess_cols = [
'Possess_Television',
'Possess_Laptop',
'Possess_Mobile',
'Possess_Bicycle',
'Possess_Scooter',
'Possess_Car',
'Possess_Refrigerator',
'Possess_WashingMachine',
'Possess_AirCooler',
'TV_Facility_Type',
]

all_cols = (
    online_cols 
    + free_cols
    + possess_cols
)
pdf = pdf[all_cols]

display(f"Desire Filter shape {pdf.shape}")
# Out:
# 'Desire Filter shape (28210, 14)'

# %%
def unique_values(cols: list[str]) -> None:
    for col in pdf[cols].columns:
        display(pdf[col].value_counts())

# %%
unique_values(cols=online_cols)
# Out:
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ Online_Clothing ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ 0               ┆ 23808 │
# │ 1               ┆ 4402  │
# └─────────────────┴───────┘
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ Online_Footwear ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ 0               ┆ 25176 │
# │ 1               ┆ 3034  │
# └─────────────────┴───────┘

# %%
unique_values(cols=free_cols)
# Out:
# shape: (2, 2)
# ┌───────────────┬───────┐
# │ Free_Clothing ┆ count │
# │ ---           ┆ ---   │
# │ i16           ┆ u32   │
# ╞═══════════════╪═══════╡
# │ 1             ┆ 1694  │
# │ 0             ┆ 26516 │
# └───────────────┴───────┘
# shape: (13, 2)
# ┌───────────────────┬───────┐
# │ Num_Free_Clothing ┆ count │
# │ ---               ┆ ---   │
# │ i16               ┆ u32   │
# ╞═══════════════════╪═══════╡
# │ 12                ┆ 2     │
# │ 9                 ┆ 2     │
# │ 5                 ┆ 4     │
# │ 15                ┆ 2     │
# │ 4                 ┆ 214   │
# │ …                 ┆ …     │
# │ 1                 ┆ 506   │
# │ 0                 ┆ 26516 │
# │ 6                 ┆ 88    │
# │ 8                 ┆ 8     │
# │ 3                 ┆ 116   │
# └───────────────────┴───────┘

# %%
for col in ['Num_Free_Clothing', 'Free_Clothing']:
    pdf = pdf.with_columns(
    pl.col(col).fill_null(strategy='zero')
)

# %%
unique_values(cols=possess_cols)
# Out:
# shape: (2, 2)
# ┌────────────────────┬───────┐
# │ Possess_Television ┆ count │
# │ ---                ┆ ---   │
# │ i16                ┆ u32   │
# ╞════════════════════╪═══════╡
# │ 1                  ┆ 20772 │
# │ 0                  ┆ 7438  │
# └────────────────────┴───────┘
# shape: (2, 2)
# ┌────────────────┬───────┐
# │ Possess_Laptop ┆ count │
# │ ---            ┆ ---   │
# │ i16            ┆ u32   │
# ╞════════════════╪═══════╡
# │ 0              ┆ 26636 │
# │ 1              ┆ 1574  │
# └────────────────┴───────┘
# shape: (2, 2)
# ┌────────────────┬───────┐
# │ Possess_Mobile ┆ count │
# │ ---            ┆ ---   │
# │ i16            ┆ u32   │
# ╞════════════════╪═══════╡
# │ 0              ┆ 666   │
# │ 1              ┆ 27544 │
# └────────────────┴───────┘
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ Possess_Bicycle ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ 0               ┆ 16528 │
# │ 1               ┆ 11682 │
# └─────────────────┴───────┘
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ Possess_Scooter ┆ count │
# │ ---             ┆ ---   │
# │ i16             ┆ u32   │
# ╞═════════════════╪═══════╡
# │ 1               ┆ 21326 │
# │ 0               ┆ 6884  │
# └─────────────────┴───────┘
# shape: (2, 2)
# ┌─────────────┬───────┐
# │ Possess_Car ┆ count │
# │ ---         ┆ ---   │
# │ i16         ┆ u32   │
# ╞═════════════╪═══════╡
# │ 1           ┆ 1804  │
# │ 0           ┆ 26406 │
# └─────────────┴───────┘
# shape: (2, 2)
# ┌──────────────────────┬───────┐
# │ Possess_Refrigerator ┆ count │
# │ ---                  ┆ ---   │
# │ i16                  ┆ u32   │
# ╞══════════════════════╪═══════╡
# │ 0                    ┆ 18596 │
# │ 1                    ┆ 9614  │
# └──────────────────────┴───────┘
# shape: (2, 2)
# ┌────────────────────────┬───────┐
# │ Possess_WashingMachine ┆ count │
# │ ---                    ┆ ---   │
# │ i16                    ┆ u32   │
# ╞════════════════════════╪═══════╡
# │ 1                      ┆ 4306  │
# │ 0                      ┆ 23904 │
# └────────────────────────┴───────┘
# shape: (2, 2)
# ┌───────────────────┬───────┐
# │ Possess_AirCooler ┆ count │
# │ ---               ┆ ---   │
# │ i16               ┆ u32   │
# ╞═══════════════════╪═══════╡
# │ 1                 ┆ 19784 │
# │ 0                 ┆ 8426  │
# └───────────────────┴───────┘
# shape: (3, 2)
# ┌──────────────────┬───────┐
# │ TV_Facility_Type ┆ count │
# │ ---              ┆ ---   │
# │ i16              ┆ u32   │
# ╞══════════════════╪═══════╡
# │ 2                ┆ 2546  │
# │ 3                ┆ 23354 │
# │ 1                ┆ 2310  │
# └──────────────────┴───────┘

# %%
pc = ['Possess_Television', 'Possess_Laptop', 'Possess_Mobile', 'Possess_Bicycle',
 'Possess_Scooter', 'Possess_Car', 'Possess_Refrigerator', 'Possess_WashingMachine',
 'Possess_AirCooler', 'Online_Clothing', 'Online_Footwear']

for col in pc:
        pdf = pdf.with_columns(
        pl.col(col).fill_null(strategy='zero')
)

# %%
pdf = pdf.with_columns(
        pl.col('TV_Facility_Type').fill_null(strategy='forward')
)
