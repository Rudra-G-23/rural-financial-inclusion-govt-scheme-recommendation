# %%
""" 
Goal: In this notebook we convert the dta & sav file format to csv 

Author: Rudra Prasad Bhuyan
Starting Time: 24-102025 08:19 IST
"""
print("")

# %%
# !pip install pyreadstat -q

# %%
import pandas as pd
import pyreadstat

# %%
#  Import form the local path

lev_01_path  = "raw-data\LEVEL - 01(Section 1 and 1.1).sav"
lev_02_path  = "raw-data\LEVEL - 02 (Section 3).sav"
lev_03_path  = "raw-data\LEVEL - 03.sav"
lev_04_path  = "raw-data/LEVEL - 04 (Section 4.1).sav"
lev_05_path  = "raw-data\LEVEL - 05 ( Sec 5 & 6).dta"
lev_06_path  = "raw-data\LEVEL - 06 (Section 7).dta"
lev_07_path  = "raw-data\LEVEL - 07 (Section 4.dta"
lev_08_path  = "raw-data\LEVEL - 08 (Section 8.dta"
lev_09_path  = "raw-data\LEVEL - 09 (Section 9 & 10 & 11).dta"
lev_10_path  = "raw-data\LEVEL - 10 (Section 12).dta"
lev_11_path  = "raw-data\LEVEL - 11 (Section 4.dta"
lev_12_path  = "raw-data\LEVEL - 12 (Section 13).dta"
lev_13_path  = "raw-data\Level - 13 (Section 14).dta"
lev_14_path  = "raw-data\LEVEL - 14 (Section  A1,B1 & C1).dta"
lev_15_path  = "raw-data\LEVEL - 15 (Section 1.dta"

# %%
for i in range(1, 16):
    if i < 10:
        try:
            df, meta = pyreadstat.read_sav(f"lev_{i:02d}_path")
            df.to_csv(f"lev_{l}", index=False, encoding='utf-8')
            print(f"✅ Conversion complete! CSV saved: lev_{i}.csv")
        except:
            df, meta = pyreadstat.read_dta(f"lev_{i:02d}_path")
            df.to_csv(f"lev_{l}", index=False, encoding='utf-8')
            print(f"✅ Conversion complete! CSV saved: lev_{i}.csv")
    else:
        try:
            df, meta = pyreadstat.read_sav(f"lev_{i:02d}_path")
            df.to_csv(f"lev_{l}", index=False, encoding='utf-8')
            print(f"✅ Conversion complete! CSV saved: lev_{i}.csv")
        except:
            df, meta = pyreadstat.read_dta(f"lev_{i:02d}_path")
            df.to_csv(f"lev_{l}", index=False, encoding='utf-8')
            print(f"✅ Conversion complete! CSV saved: lev_{i}.csv")
# Out:
# ---------------------------------------------------------------------------
# PyreadstatError                           Traceback (most recent call last)
# Cell In[19], line 4
#       3 try:
# ----> 4     df, meta = pyreadstat.read_sav(f"lev_{i:02d}_path")
#       5     df.to_csv(f"lev_{l}", index=False, encoding='utf-8')
#
# File pyreadstat/pyreadstat.pyx:391, in pyreadstat.pyreadstat.read_sav()
#
# File pyreadstat/_readstat_parser.pyx:1195, in pyreadstat._readstat_parser.run_conversion()
#
# PyreadstatError: File lev_01_path does not exist!
#
# During handling of the above exception, another exception occurred:
#
# PyreadstatError                           Traceback (most recent call last)
# Cell In[19], line 8
#       6     print(f"✅ Conversion complete! CSV saved: lev_{i}.csv")
#       7 except:
# ----> 8     df, meta = pyreadstat.read_dta(f"lev_{i:02d}_path")
#       9     df.to_csv(f"lev_{l}", index=False, encoding='utf-8')
#      10     print(f"✅ Conversion complete! CSV saved: lev_{i}.csv")
#
# File pyreadstat/pyreadstat.pyx:296, in pyreadstat.pyreadstat.read_dta()
#
# File pyreadstat/_readstat_parser.pyx:1195, in pyreadstat._readstat_parser.run_conversion()
#
# PyreadstatError: File lev_01_path does not exist!

# %%
lev_01_path  = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\raw-data\LEVEL - 01(Section 1 and 1.1).sav"
csv_file_path = "level-01.csv"  # replace with desired .csv file path

df, meta = pyreadstat.read_sav(lev_01_path)
df.to_csv(csv_file_path, index=False, encoding='utf-8')

# %%
import pyreadstat
df, meta = pyreadstat.read_sav(r"raw-data\LEVEL - 02 (Section 3).dta")
print(df.shape)
print(meta.number_rows, meta.number_columns)
# Out:
# ---------------------------------------------------------------------------
# PyreadstatError                           Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pyreadstat
# ----> 2 df, meta = pyreadstat.read_sav(r"raw-data\LEVEL - 02 (Section 3).dta")
#       3 print(df.shape)
#       4 print(meta.number_rows, meta.number_columns)
#
# File pyreadstat/pyreadstat.pyx:391, in pyreadstat.pyreadstat.read_sav()
#
# File pyreadstat/_readstat_parser.pyx:1195, in pyreadstat._readstat_parser.run_conversion()
#
# PyreadstatError: File raw-data\LEVEL - 02 (Section 3).dta does not exist!

# %%
print(dir(meta))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'column_labels', 'column_names', 'column_names_to_labels', 'creation_time', 'file_encoding', 'file_format', 'file_label', 'missing_ranges', 'missing_user_values', 'modification_time', 'mr_sets', 'notes', 'number_columns', 'number_rows', 'original_variable_types', 'readstat_variable_types', 'table_name', 'value_labels', 'variable_alignment', 'variable_display_width', 'variable_measure', 'variable_storage_width', 'variable_to_label', 'variable_value_labels']

# %%
"creation_time" = meta.creation_time,
"modification_time": meta.modification_time

# %%
['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', 
 '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', 
 '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', 
 '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__',
 '__weakref__', 
 'column_labels', 'column_names', 
 'column_names_to_labels', 'creation_time',
 'file_encoding',
 'file_format', 'file_label', 'missing_ranges',
 'missing_user_values', 'modification_time',
 'mr_sets', 'notes', 'number_columns', 'number_rows', 'original_variable_types',
 'readstat_variable_types', 'table_name', 'value_labels', 'variable_alignment', 
 'variable_display_width', 'variable_measure', 'variable_storage_width', 'variable_to_label', 'variable_value_labels']
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'column_labels',
#  'column_names',
#  'column_names_to_labels',
#  'creation_time',
#  'file_encoding',
#  'file_format',
#  'file_label',
#  'missing_ranges',
#  'missing_user_values',
#  'modification_time',
#  'mr_sets',
#  'notes',
#  'number_columns',
#  'number_rows',
#  'original_variable_types',
#  'readstat_variable_types',
#  'table_name',
#  'value_labels',
#  'variable_alignment',
#  'variable_display_width',
#  'variable_measure',
#  'variable_storage_width',
#  'variable_to_label',
#  'variable_value_labels']

# %%
metadata = {
    "rows": meta.number_rows,
    "columns": meta.number_columns,
    "missing_ranges": meta.missing_ranges,
    "missing_user_values": meta.missing_user_values,
    "notes": meta.notes,
    "original_variables_type": meta.original_variable_types,
    "readstat_variable_types": meta.readstat_variable_types,
    "table_name": meta.table_name,
    "value_labels": meta.value_labels,
    "Variable_labels": meta.column_labels,
    "Value_labels":  meta.value_labels
}

# %%
df = pd.read_parquet(r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\lev_01.parquet")

# %%
df.shape
# Out:
# (261953, 21)

# %%
df.shape[0]
# Out:
# 261953

# %% [markdown]
# ## Where is the issues for 12, 13, 14

# %%
path = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\raw-data\LEVEL - 12 (Section 13).dta"

with open(path, "rb") as f:
    header = f.read(200)
print(header[:60])
# Out:
# b'q\x02\x01\x00\x16\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
import mimetypes
mimetypes.guess_type(r"LEVEL - 12 (Section 13).dta")
# Out:
# (None, None)

# %%
with open(path, "rb") as f:
    print(f.read(4))
# Out:
# b'q\x02\x01\x00'

# %%
import os
print(os.path.getsize(path))
# Out:
# 173342780

# %%
with open(path, "rb") as f:
    header = f.read(64)
print(header)
# Out:
# b'q\x02\x01\x00\x16\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
import zipfile
zipfile.is_zipfile(path)
# Out:
# False

# %%
import magic

path = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\raw-data\LEVEL - 12 (Section 13).dta"
print(magic.from_file(path))
with open(path, "rb") as f:
    print(f.read(16))
# Out:
# data
# b'q\x02\x01\x00\x16\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
l9_path = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\raw-data\LEVEL - 09 (Section 9 & 10 & 11).dta"

with open(l9_path, "rb") as f:
    header = f.read(200)
print(header[:60])
# Out:
# b'q\x02\x01\x00\x15\x000\x06~\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
