# %%
import polars as pl

# %%
path = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\parquet-data\lev-02\data\lev-02_merged.parquet"

df = pl.read_parquet(path)

# %%
df.shape
# Out:
# (1107221, 36)

# %%
df = df.filter(pl.col("State") == '10')

# %%
df.shape
# Out:
# (85751, 36)

# %%
import polars.selectors as cs

# Cast all currently string columns to Float, but only if they are numeric
df = df.with_columns(
    cs.string().cast(pl.Int32, strict=False)
)

# %%
df.schema
# Out:
# Schema([('Survey_Name', Int32),
#         ('Year', Int32),
#         ('FSU_Serial_No', Int32),
#         ('Sector', Int32),
#         ('State', Int32),
#         ('NSS_Region', Int32),
#         ('District', Int32),
#         ('Stratum', Int32),
#         ('Sub_stratum', Int32),
#         ('Panel', Int32),
#         ('Sub_sample', Int32),
#         ('FOD_Sub_Region', Int32),
#         ('Sample_SU_No', Int32),
#         ('Sample_Sub_Division_No', Int32),
#         ('Second_Stage_Stratum_No', Int32),
#         ('Sample_Household_No', Int32),
#         ('Questionnaire_No', Int32),
#         ('Level', Int32),
#         ('Person_Serial_No', Int32),
#         ('Relation_to_Head', Int32),
#         ('Gender', Int32),
#         ('Age', Int32),
#         ('Marital_Status', Int32),
#         ('Education_Level', Int32),
#         ('Years_of_Education', Int32),
#         ('Used_Internet_Last_30_Days', Int32),
#         ('Days_Away_From_Home_Last_30_Days', Int32),
# ...

# %%
df = df.filter(pl.col("State") == 10)

# %%
df
# Out:
# shape: (85_751, 36)
# ┌─────────────┬──────┬────────────┬────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ Survey_Name ┆ Year ┆ FSU_Serial ┆ Sector ┆ … ┆ Meals_At_H ┆ Revisit_St ┆ FDQ_Origin ┆ Multiplier │
# │ ---         ┆ ---  ┆ _No        ┆ ---    ┆   ┆ ome        ┆ atus       ┆ al_Member  ┆ ---        │
# │ i32         ┆ i32  ┆ ---        ┆ i32    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ i64        │
# │             ┆      ┆ i32        ┆        ┆   ┆ i32        ┆ i32        ┆ i32        ┆            │
# ╞═════════════╪══════╪════════════╪════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ null        ┆ 2024 ┆ 43528      ┆ 1      ┆ … ┆ 90         ┆ 1          ┆ 1          ┆ 114450     │
# │ null        ┆ 2024 ┆ 43528      ┆ 1      ┆ … ┆ 90         ┆ 1          ┆ 1          ┆ 114450     │
# │ null        ┆ 2024 ┆ 43528      ┆ 1      ┆ … ┆ 90         ┆ 1          ┆ 1          ┆ 114450     │
# ...

# %%
df
# Out:
# shape: (85_751, 36)
# ┌─────────────┬──────┬────────────┬────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ Survey_Name ┆ Year ┆ FSU_Serial ┆ Sector ┆ … ┆ Meals_At_H ┆ Revisit_St ┆ FDQ_Origin ┆ Multiplier │
# │ ---         ┆ ---  ┆ _No        ┆ ---    ┆   ┆ ome        ┆ atus       ┆ al_Member  ┆ ---        │
# │ i32         ┆ i32  ┆ ---        ┆ i32    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ i64        │
# │             ┆      ┆ i32        ┆        ┆   ┆ i32        ┆ i32        ┆ i32        ┆            │
# ╞═════════════╪══════╪════════════╪════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ null        ┆ 2024 ┆ 43528      ┆ 1      ┆ … ┆ 90         ┆ 1          ┆ 1          ┆ 114450     │
# │ null        ┆ 2024 ┆ 43528      ┆ 1      ┆ … ┆ 90         ┆ 1          ┆ 1          ┆ 114450     │
# │ null        ┆ 2024 ┆ 43528      ┆ 1      ┆ … ┆ 90         ┆ 1          ┆ 1          ┆ 114450     │
# ...

# %%
df.write_csv("test-bihar.csv")
