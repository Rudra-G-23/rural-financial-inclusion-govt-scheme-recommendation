# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\bihar-datasets\BL01.csv")
df3 = pd.read_csv(r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\bihar-datasets\BL03.csv")
# Out:
# C:\Users\Rudra\AppData\Local\Temp\ipykernel_22296\3949611226.py:2: DtypeWarning: Columns (45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv(r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\bihar-datasets\BL03.csv")

# %%
df1.columns
# Out:
# Index(['Survey_Name', 'Year', 'FSU_Serial_No', 'Sector', 'State', 'NSS_Region',
#        'District', 'Stratum', 'Sub_stratum', 'Panel', 'Sub_sample',
#        'FOD_Sub_Region', 'Sample_SU_No', 'Sample_Sub_Division_No',
#        'Second_Stage_Stratum_No', 'Sample_Household_No', 'Questionnaire_No',
#        'Level', 'Survey_Code', 'Reason_for_Substitution_Code', 'Multiplier',
#        'Sector_label', 'State_label', 'Survey_Code_label',
#        'Reason_for_Substitution_Code_label', 'ingest_timestamp',
#        'ingest_date'],
#       dtype='object')

# %%
'8' + '9'
# Out:
# '89'

# %%
df1['Year'].convert_dtypes()
# Out:
# 0        2024
# 1        2024
# 2        2024
# 3        2024
# 4        2024
#          ...
# 17250    2024
# 17251    2024
# 17252    2024
# 17253    2024
# 17254    2024
# Name: Year, Length: 17255, dtype: Int64

# %%
df1['Year'].astype(dtype='string') + df1['FSU_Serial_No'].astype(dtype='string')
# Out:
# 0        202443423
# 1        202443423
# 2        202443423
# 3        202443423
# 4        202443423
#            ...
# 17250    202443427
# 17251    202443427
# 17252    202443427
# 17253    202443427
# 17254    202443423
# Length: 17255, dtype: string

# %%
combine_cols = ['FSU_Serial_No', 'Sector', 'State', 'NSS_Region',
       'District', 'Stratum', 'Sub_stratum', 'Panel', 'Sub_sample',
       'FOD_Sub_Region', 'Sample_SU_No', 'Sample_Sub_Division_No',
       'Second_Stage_Stratum_No', 'Sample_Household_No',]

# %%
df1[combine_cols].notnull().sum()
# Out:
# FSU_Serial_No              17255
# Sector                     17255
# State                      17255
# NSS_Region                 17255
# District                   17255
# Stratum                    17255
# Sub_stratum                17255
# Panel                      17255
# Sub_sample                 17255
# FOD_Sub_Region             17255
# Sample_SU_No               17255
# Sample_Sub_Division_No        44
# Second_Stage_Stratum_No    17255
# Sample_Household_No        17255
# dtype: int64

# %%
df1['Sample_Sub_Division_No'].unique()
# Out:
# array([nan,  2.,  1.])

# %%
df1[combine_cols].astype(str).agg("".join, axis=1)
# Out:
# 0         434231101011923276210113nan32
# 1         434231101011923276210113nan33
# 2         434231101011923276210113nan34
# 3         434231101011923276210113nan35
# 4         434231101011923276210113nan36
#                       ...
# 17250    434271101011323275210116nan315
# 17251    434271101011323275210116nan316
# 17252    434271101011323275210116nan317
# 17253    434271101011323275210116nan318
# 17254     434231101011923276210113nan31
# Length: 17255, dtype: object

# %%
df1['hh_unique_id'] = df1[combine_cols].fillna(0).astype(int).astype(str).agg("".join, axis=1)

# %%
df3['hh_unique_id'] = df3[combine_cols].fillna(0).astype(int).astype(str).agg("".join, axis=1)

# %%
dfm = df1.merge(df3, on='hh_unique_id')

# %%
dfm
# Out:
#       Survey_Name_x  Year_x  FSU_Serial_No_x  Sector_x  State_x  NSS_Region_x  \
# 0              HCES    2024            43423         1       10           101
# 1              HCES    2024            43423         1       10           101
# 2              HCES    2024            43423         1       10           101
# 3              HCES    2024            43423         1       10           101
# 4              HCES    2024            43423         1       10           101
# ...             ...     ...              ...       ...      ...           ...
# 17250          HCES    2024            43427         1       10           101
# 17251          HCES    2024            43427         1       10           101
# 17252          HCES    2024            43427         1       10           101
# 17253          HCES    2024            43427         1       10           101
# 17254          HCES    2024            43423         1       10           101
#
# ...

# %%
dfm.columns
# Out:
# Index(['Survey_Name_x', 'Year_x', 'FSU_Serial_No_x', 'Sector_x', 'State_x',
#        'NSS_Region_x', 'District_x', 'Stratum_x', 'Sub_stratum_x', 'Panel_x',
#        'Sub_sample_x', 'FOD_Sub_Region_x', 'Sample_SU_No_x',
#        'Sample_Sub_Division_No_x', 'Second_Stage_Stratum_No_x',
#        'Sample_Household_No_x', 'Questionnaire_No_x', 'Level_x', 'Survey_Code',
#        'Reason_for_Substitution_Code', 'Multiplier_x', 'Sector_label_x',
#        'State_label_x', 'Survey_Code_label',
#        'Reason_for_Substitution_Code_label', 'ingest_timestamp_x',
#        'ingest_date_x', 'hh_unique_id', 'Survey_Name_y', 'Year_y',
#        'FSU_Serial_No_y', 'Sector_y', 'State_y', 'NSS_Region_y', 'District_y',
#        'Stratum_y', 'Sub_stratum_y', 'Panel_y', 'Sub_sample_y',
#        'FOD_Sub_Region_y', 'Sample_SU_No_y', 'Sample_Sub_Division_No_y',
#        'Second_Stage_Stratum_No_y', 'Sample_Household_No_y',
#        'Questionnaire_No_y', 'Level_y', 'HH_Size_FDQ',
# ...

# %% [markdown]
# - Yes i did it 🙌
# - We create a unique id
# - How to do this

# %% [markdown]
# only Bihar data
#
# 	L01 -> 17_255
# 	L03 -> 17_255
# 	4 -> 17_255
# 	7 -> 17_255
# 	11 -> 17_255
#
#
# Item code contains:
# ```
# 2 -> 85_751
# 5 -> 8_41_515
# 6 -> 1_13_362
# 8 -> 97_939
# 9 -> 5_42_787
# 10 -> 63_517
# 12 -> 3_24_076
# 13 -> 3_58_548
# 14 -> ?
# 15 -> 69_020 (response, information CODE )
# ```
# 13_83_097
#
# Analysis
# 1
# 2
# 5
# 9
#
# Finding
# -
