# %%
import pandas as pd
import findmyjoint as fmj

# %%
df1 = pd.read_csv(r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\bihar-datasets\BL01.csv")
df2 = pd.read_csv(r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\bihar-datasets\BL02.csv")
df3 = pd.read_csv(r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\bihar-datasets\BL02.csv")

# %%
df1.columns
# Out:
# Index(['Survey_Name', 'Year', 'FSU_Serial_No', 'Sector', 'State', 'NSS_Region',
#        'District', 'Stratum', 'Sub_stratum', 'Panel', 'Sub_sample',
#        'FOD_Sub_Region', 'Sample_SU_No', 'Sample_Sub_Division_No',
#        'Second_Stage_Stratum_No', 'Sample_Household_No', 'Questionnaire_No',
#        'Level', 'Survey_Code', 'Reason_for_Substitution_Code', 'Multiplier',
#        'Sector_label', 'State_label', 'Survey_Code_label',
#        'Reason_for_Substitution_Code_label', 'ingest_timestamp',
#        'ingest_date'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Survey_Name', 'Year', 'FSU_Serial_No', 'Sector', 'State', 'NSS_Region',
#        'District', 'Stratum', 'Sub_stratum', 'Panel', 'Sub_sample',
#        'FOD_Sub_Region', 'Sample_SU_No', 'Sample_Sub_Division_No',
#        'Second_Stage_Stratum_No', 'Sample_Household_No', 'Questionnaire_No',
#        'Level', 'Person_Serial_No', 'Relation_to_Head', 'Gender', 'Age',
#        'Marital_Status', 'Education_Level', 'Years_of_Education',
#        'Used_Internet_Last_30_Days', 'Days_Away_From_Home_Last_30_Days',
#        'Meals_Usually_Taken_Per_Day', 'Meals_From_School',
#        'Meals_From_Employer', 'Meals_Other', 'Meals_On_Payment',
#        'Meals_At_Home', 'Revisit_Status', 'FDQ_Original_Member', 'Multiplier',
#        'Sector_label', 'State_label', 'Relation_to_Head_label', 'Gender_label',
#        'Marital_Status_label', 'Education_Level_label',
#        'Used_Internet_Last_30_Days_label', 'ingest_timestamp', 'ingest_date'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Survey_Name', 'Year', 'FSU_Serial_No', 'Sector', 'State', 'NSS_Region',
#        'District', 'Stratum', 'Sub_stratum', 'Panel', 'Sub_sample',
#        'FOD_Sub_Region', 'Sample_SU_No', 'Sample_Sub_Division_No',
#        'Second_Stage_Stratum_No', 'Sample_Household_No', 'Questionnaire_No',
#        'Level', 'Person_Serial_No', 'Relation_to_Head', 'Gender', 'Age',
#        'Marital_Status', 'Education_Level', 'Years_of_Education',
#        'Used_Internet_Last_30_Days', 'Days_Away_From_Home_Last_30_Days',
#        'Meals_Usually_Taken_Per_Day', 'Meals_From_School',
#        'Meals_From_Employer', 'Meals_Other', 'Meals_On_Payment',
#        'Meals_At_Home', 'Revisit_Status', 'FDQ_Original_Member', 'Multiplier',
#        'Sector_label', 'State_label', 'Relation_to_Head_label', 'Gender_label',
#        'Marital_Status_label', 'Education_Level_label',
#        'Used_Internet_Last_30_Days_label', 'ingest_timestamp', 'ingest_date'],
#       dtype='object')

# %%
cols_02 = [
   'FSU_Serial_No', 'Sector', 'State', 'NSS_Region',
    'District', 'Stratum', 'Sub_stratum', 'Panel', 'Sub_sample',
    'FOD_Sub_Region', 'Sample_SU_No', 'Sample_Sub_Division_No',
    'Second_Stage_Stratum_No', 'Sample_Household_No', 'Questionnaire_No',
    'Level', 'Person_Serial_No',  
]

cols_03 = [
    'FSU_Serial_No', 'Sector', 'State', 'NSS_Region',
    'District', 'Stratum', 'Sub_stratum', 'Panel', 'Sub_sample',
    'FOD_Sub_Region', 'Sample_SU_No', 'Sample_Sub_Division_No',
    'Second_Stage_Stratum_No', 'Sample_Household_No', 'Questionnaire_No',
    'Level', 'Person_Serial_No', 
]

# %%
df2 = df2[cols_02]
df3 = df3[cols_03]

# %%
datasets = [df1, df2, df3]

# %%
matrix = fmj.compare(datasets=datasets)

# %%
matrix
# Out:
#     dataset_left  column_left dataset_right column_right  name_sim  \
# 0            ds0        State           ds1        State  1.000000
# 1            ds0        State           ds2        State  1.000000
# 2            ds0       Sector           ds1       Sector  1.000000
# 3            ds0     District           ds2     District  1.000000
# 4            ds0     District           ds1     District  1.000000
# ..           ...          ...           ...          ...       ...
# 222          ds0  State_label           ds2        State  0.625000
# 223          ds0  State_label           ds1        State  0.625000
# 224          ds0  ingest_date           ds2        State  0.625000
# 225          ds0  Survey_Name           ds2   Sub_sample  0.571429
# 226          ds0  Survey_Name           ds1   Sub_sample  0.571429
#
#      dtype_match  content_sim  suggestion  edge_weight
# 0            1.0          1.0  Merge-safe     1.000000
# ...

# %%
fmj.network(datasets)
# Out:
# No matches found. Running match_columns() first...
# Building graph with connections stronger than 0.5...
# ...
# joint_graph.html
# Success! Interactive graph saved to: c:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\notebooks\merging-dataset\bihar-data\joint_graph.html
# Opening in your default browser...
