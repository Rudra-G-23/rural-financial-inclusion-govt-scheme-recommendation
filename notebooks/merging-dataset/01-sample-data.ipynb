# %%
import polars as pl

# %% [markdown]
# - This notebooks used as the testing for the script
# - For script, checkout the script section name `sample-csv.py`

# %%
path = r"C:\Users\Rudra\Desktop\rural-financial-inclusion-govt-scheme-recommendation\parquet-data\lev-01\data\lev-01_merged.parquet"

# %%
df = pl.read_parquet(path, n_rows=100)

# %%
df.shape
# Out:
# (100, 21)

# %%
df
# Out:
# shape: (100, 21)
# ┌─────────────┬──────┬──────────────┬────────┬───┬───────┬─────────────┬──────────────┬────────────┐
# │ Survey_Name ┆ Year ┆ FSU_Serial_N ┆ Sector ┆ … ┆ Level ┆ Survey_Code ┆ Reason_for_S ┆ Multiplier │
# │ ---         ┆ ---  ┆ o            ┆ ---    ┆   ┆ ---   ┆ ---         ┆ ubstitution_ ┆ ---        │
# │ str         ┆ str  ┆ ---          ┆ str    ┆   ┆ str   ┆ str         ┆ Code         ┆ f64        │
# │             ┆      ┆ str          ┆        ┆   ┆       ┆             ┆ ---          ┆            │
# │             ┆      ┆              ┆        ┆   ┆       ┆             ┆ str          ┆            │
# ╞═════════════╪══════╪══════════════╪════════╪═══╪═══════╪═════════════╪══════════════╪════════════╡
# │ HCES        ┆ 2024 ┆ 46667        ┆ 1      ┆ … ┆ 01    ┆ 1           ┆              ┆ 16669.0    │
# │ HCES        ┆ 2024 ┆ 46667        ┆ 1      ┆ … ┆ 01    ┆ 1           ┆              ┆ 24840.0    │
# ...

# %%
df = df.with_columns(
    [pl.col(col).cast(pl.Int32, strict=False) for col in df.columns]
)

# %%
df.write_csv("lev01.csv")
